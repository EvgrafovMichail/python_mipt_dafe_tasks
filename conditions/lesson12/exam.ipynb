# %%
def get_progression_computer(start, step):
    count = 0
    def get_num():
        nonlocal count
        count += step
        return start + count
    return get_num

get = get_progression_computer(1, 0.5)
get()
get()
get()
# Out:
# 2.5

# %%
def sort_list(lst):
    return sorted(lst, key = len)
            

print(sort_list(['av', 'saa', 'a']))
# Out:
# ['a', 'av', 'saa']
